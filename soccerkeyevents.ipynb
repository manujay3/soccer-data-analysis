# %%
import pandas as pd
import os
import datetime
import kaggle
import zipfile


from directory import KAGGLE_DATASET_SLUG, KAGGLE_DATA_ROOT, BASE_DATA_DIR, PLAYS_DATA_DIR
from directory import KEY_EVENTS_DATA_DIR


if not os.path.exists(KAGGLE_DATA_ROOT):
    print(f"Data directory '{KAGGLE_DATA_ROOT}' not found. Downloading from Kaggle...")

    print(f"Downloading dataset '{KAGGLE_DATASET_SLUG}'...")
    kaggle.api.dataset_download_files(
        KAGGLE_DATASET_SLUG,
        path=KAGGLE_DATA_ROOT,
        unzip=True
    )
    print(f"✅ Download and unzip complete.")
else:
    print(f"Data directory '{KAGGLE_DATA_ROOT}' already exists. Skipping download.")

df_leagues = pd.read_csv(BASE_DATA_DIR + "/leagues.csv")
df_players = pd.read_csv(BASE_DATA_DIR + "/players.csv", low_memory=False)
df_teams = pd.read_csv(BASE_DATA_DIR + "/teams.csv")
df_fixtures = pd.read_csv(BASE_DATA_DIR + "/fixtures.csv")
df_teamStats = pd.read_csv(BASE_DATA_DIR + "/teamStats.csv")
df_teamRoster = pd.read_csv(BASE_DATA_DIR + "/teamRoster.csv")
df_keyEventDescription = pd.read_csv(BASE_DATA_DIR + "/keyEventDescription.csv")
df_status = pd.read_csv(BASE_DATA_DIR + "/status.csv")
df_venues = pd.read_csv(BASE_DATA_DIR + "/venues.csv")
df_standings = pd.read_csv(BASE_DATA_DIR + "/standings.csv")
# Out:
# Data directory './kaggle_data' already exists. Skipping download.

# %%
# Ask the user for the specific 'plays' file they want to analyze
keyEvents_filename = input("Enter the 'Key Events' file name (e.g., keyEvents_2024_ENG.1): ")

# Construct the full file path
full_keyEvents_path = KEY_EVENTS_DATA_DIR + '/' + keyEvents_filename + ".csv"

print(f"--- Loading plays data from: {full_keyEvents_path} ---")

# Load the specified CSV file
# I've added low_memory=False, as 'plays' files can be very large
try:
    df_keyEvents = pd.read_csv(full_keyEvents_path, low_memory=False)
    print("✅ Plays file loaded successfully!")
except FileNotFoundError:
    print(f"❌ ERROR: File not found at {full_keyEvents_path}")
    print("Please check the filename and try again.")
except Exception as e:
    print(f"An error occurred: {e}")

# This cell is now separate, so you can inspect df_plays after loading
# Out:
# --- Loading plays data from: ./kaggle_data/keyEvents_data/keyEvents_2024_ENG.1.csv ---
# ✅ Plays file loaded successfully!

# %%
df_keyEvents = pd.merge(df_keyEvents,df_teams, how="left", left_on=['teamId'],right_on=['teamId'])
df_keyEvents.rename(columns={'name':'team'},inplace=True)

df_keyEvents
# Out:
#        seasonType  eventId  keyEventOrder    playId  keyEventTypeId  period  \
# 0           12654   704279              1  43556191              80       1
# 1           12654   704279              2  43556383              94       1
# 2           12654   704279              3  43556498              94       1
# 3           12654   704279              4  43556737              94       1
# 4           12654   704279              5  43556797              81       1
# ...           ...      ...            ...       ...             ...     ...
# 14699       12654   704658             18  45319232              76       2
# 14700       12654   704658             18  45319232              76       2
# 14701       12654   704658             19  45319290              98       2
# 14702       12654   704658             21  45319509              83       2
# 14703       12654   704658             20  45319466              94       2
#
#        clockValue clockDisplayValue  scoringPlay  shootout  ...  \
# 0               0               NaN            0         0  ...
# 1            1038               18'            0         0  ...
# 2            1497               25'            0         0  ...
# 3            2394               40'            0         0  ...
# 4            2700            45'+1'            0         0  ...
# ...           ...               ...          ...       ...  ...
# 14699        4990               84'            0         0  ...
# 14700        4990               84'            0         0  ...
# 14701        5205               87'            1         0  ...
# 14702        5400            90'+9'            0         0  ...
# 14703        5400            90'+4'            0         0  ...
#
#                 location               team  abbreviation        displayName  \
# 0                    NaN                NaN           NaN                NaN
# 1      Manchester United  Manchester United           MAN  Manchester United
# 2                 Fulham             Fulham           FUL             Fulham
# 3      Manchester United  Manchester United           MAN  Manchester United
# 4                    NaN                NaN           NaN                NaN
# ...                  ...                ...           ...                ...
# 14699        Aston Villa        Aston Villa           AVL        Aston Villa
# 14700        Aston Villa        Aston Villa           AVL        Aston Villa
# 14701  Manchester United  Manchester United           MAN  Manchester United
# 14702                NaN                NaN           NaN                NaN
# 14703  Manchester United  Manchester United           MAN  Manchester United
#
#        shortDisplayName   color  alternateColor  \
# 0                   NaN     NaN             NaN
# 1            Man United  da020e          144992
# 2                Fulham  ffffff          d11317
# 3            Man United  da020e          144992
# 4                   NaN     NaN             NaN
# ...                 ...     ...             ...
# 14699       Aston Villa  660e36          ffffff
# 14700       Aston Villa  660e36          ffffff
# 14701        Man United  da020e          144992
# 14702               NaN     NaN             NaN
# 14703        Man United  da020e          144992
#
#                                                  logoURL  venueId  \
# 0                                                    NaN      NaN
# 1      https://a.espncdn.com/i/teamlogos/soccer/500/3...    250.0
# 2      https://a.espncdn.com/i/teamlogos/soccer/500/3...    279.0
# 3      https://a.espncdn.com/i/teamlogos/soccer/500/3...    250.0
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 14699  https://a.espncdn.com/i/teamlogos/soccer/500/3...    307.0
# 14700  https://a.espncdn.com/i/teamlogos/soccer/500/3...    307.0
# 14701  https://a.espncdn.com/i/teamlogos/soccer/500/3...    250.0
# 14702                                                NaN      NaN
# 14703  https://a.espncdn.com/i/teamlogos/soccer/500/3...    250.0
#
#                   slug
# 0                  NaN
# 1          eng.man_utd
# 2           eng.fulham
# 3          eng.man_utd
# 4                  NaN
# ...                ...
# 14699  eng.aston_villa
# 14700  eng.aston_villa
# 14701      eng.man_utd
# 14702              NaN
# 14703      eng.man_utd
#
# [14704 rows x 32 columns]

# %%
df_keyEvents = pd.merge(df_keyEvents,df_keyEventDescription, how="left",
                    left_on=['keyEventTypeId'],right_on=['keyEventTypeId'])
df_keyEvents.rename(columns={'keyEventName':'keyEventDescription'},inplace=True)

# %%
df_keyEvents = pd.merge(df_keyEvents,df_players, how="left",
                    left_on=['athleteId'],right_on=['athleteId'])
#df_keyEvents.rename(columns={'displayName':'participantDisplayName'},inplace=True)
df_keyEvents = pd.merge(df_keyEvents, df_leagues, how = "left", left_on = ["seasonType"], right_on = ["seasonType"])

df_keyEvents
# Out:
#        seasonType  eventId  keyEventOrder    playId  keyEventTypeId  period  \
# 0           12654   704279              1  43556191              80       1
# 1           12654   704279              2  43556383              94       1
# 2           12654   704279              3  43556498              94       1
# 3           12654   704279              4  43556737              94       1
# 4           12654   704279              5  43556797              81       1
# ...           ...      ...            ...       ...             ...     ...
# 14699       12654   704658             18  45319232              76       2
# 14700       12654   704658             18  45319232              76       2
# 14701       12654   704658             19  45319290              98       2
# 14702       12654   704658             21  45319509              83       2
# 14703       12654   704658             20  45319466              94       2
#
#        clockValue clockDisplayValue  scoringPlay  shootout  ...  \
# 0               0               NaN            0         0  ...
# 1            1038               18'            0         0  ...
# 2            1497               25'            0         0  ...
# 3            2394               40'            0         0  ...
# 4            2700            45'+1'            0         0  ...
# ...           ...               ...          ...       ...  ...
# 14699        4990               84'            0         0  ...
# 14700        4990               84'            0         0  ...
# 14701        5205               87'            1         0  ...
# 14702        5400            90'+9'            0         0  ...
# 14703        5400            90'+4'            0         0  ...
#
#                                              headshotUrl   headshot_alt  \
# 0                                                    NaN            NaN
# 1                                                    NaN            NaN
# 2      https://a.espncdn.com/i/headshots/soccer/playe...  Calvin Bassey
# 3                                                    NaN            NaN
# 4                                                    NaN            NaN
# ...                                                  ...            ...
# 14699  https://a.espncdn.com/i/headshots/soccer/playe...  Donyell Malen
# 14700                                                NaN            NaN
# 14701                                                NaN            NaN
# 14702                                                NaN            NaN
# 14703                                                NaN            NaN
#
#                  timestamp  year                      seasonName  \
# 0                      NaN  2024  2024-25 English Premier League
# 1      2025-07-31 04:40:44  2024  2024-25 English Premier League
# 2      2025-10-14 05:15:02  2024  2024-25 English Premier League
# 3      2025-07-31 04:40:44  2024  2024-25 English Premier League
# 4                      NaN  2024  2024-25 English Premier League
# ...                    ...   ...                             ...
# 14699  2025-11-08 06:11:08  2024  2024-25 English Premier League
# 14700  2025-11-09 14:57:16  2024  2024-25 English Premier League
# 14701  2025-11-08 06:04:17  2024  2024-25 English Premier League
# 14702                  NaN  2024  2024-25 English Premier League
# 14703  2025-10-10 12:36:43  2024  2024-25 English Premier League
#
#                            seasonSlug  leagueId  midsizeName  \
# 0      2024-25-english-premier-league       700        ENG.1
# 1      2024-25-english-premier-league       700        ENG.1
# 2      2024-25-english-premier-league       700        ENG.1
# 3      2024-25-english-premier-league       700        ENG.1
# 4      2024-25-english-premier-league       700        ENG.1
# ...                               ...       ...          ...
# 14699  2024-25-english-premier-league       700        ENG.1
# 14700  2024-25-english-premier-league       700        ENG.1
# 14701  2024-25-english-premier-league       700        ENG.1
# 14702  2024-25-english-premier-league       700        ENG.1
# 14703  2024-25-english-premier-league       700        ENG.1
#
#                    leagueName  leagueShortName
# 0      English Premier League   Premier League
# 1      English Premier League   Premier League
# 2      English Premier League   Premier League
# 3      English Premier League   Premier League
# 4      English Premier League   Premier League
# ...                       ...              ...
# 14699  English Premier League   Premier League
# 14700  English Premier League   Premier League
# 14701  English Premier League   Premier League
# 14702  English Premier League   Premier League
# 14703  English Premier League   Premier League
#
# [14704 rows x 64 columns]

# %%
df_keyEvents_columns = [
        "seasonName",
        "eventId",
        "keyEventOrder",
        "playId",
        "keyEventDescription",
        "period",
        "clockDisplayValue",
        "scoringPlay",
        "shootout",
        "keyEventText",
        "keyEventShortText",
        "team",
        "participantOrder",
        "displayName_y",
        "positionName"
]
df_keyEvents = df_keyEvents[df_keyEvents_columns]

df_keyEvents
# Out:
#                            seasonName  eventId  keyEventOrder    playId  \
# 0      2024-25 English Premier League   704279              1  43556191
# 1      2024-25 English Premier League   704279              2  43556383
# 2      2024-25 English Premier League   704279              3  43556498
# 3      2024-25 English Premier League   704279              4  43556737
# 4      2024-25 English Premier League   704279              5  43556797
# ...                               ...      ...            ...       ...
# 14699  2024-25 English Premier League   704658             18  45319232
# 14700  2024-25 English Premier League   704658             18  45319232
# 14701  2024-25 English Premier League   704658             19  45319290
# 14702  2024-25 English Premier League   704658             21  45319509
# 14703  2024-25 English Premier League   704658             20  45319466
#
#       keyEventDescription  period clockDisplayValue  scoringPlay  shootout  \
# 0                 Kickoff       1               NaN            0         0
# 1             Yellow Card       1               18'            0         0
# 2             Yellow Card       1               25'            0         0
# 3             Yellow Card       1               40'            0         0
# 4                Halftime       1            45'+1'            0         0
# ...                   ...     ...               ...          ...       ...
# 14699        Substitution       2               84'            0         0
# 14700        Substitution       2               84'            0         0
# 14701    Penalty - Scored       2               87'            1         0
# 14702    End Regular Time       2            90'+9'            0         0
# 14703         Yellow Card       2            90'+4'            0         0
#
#                                             keyEventText  \
# 0                                     First Half begins.
# 1      Mason Mount (Manchester United) is shown the y...
# 2      Calvin Bassey (Fulham) is shown the yellow car...
# 3      Harry Maguire (Manchester United) is shown the...
# 4                                                    NaN
# ...                                                  ...
# 14699  Substitution, Aston Villa. Donyell Malen repla...
# 14700  Substitution, Aston Villa. Donyell Malen repla...
# 14701  Goal! Manchester United 2, Aston Villa 0. Chri...
# 14702  Second Half ends, Manchester United 2, Aston V...
# 14703  Casemiro (Manchester United) is shown the yell...
#
#                       keyEventShortText               team  participantOrder  \
# 0                                   NaN                NaN               NaN
# 1               Mason Mount Yellow Card  Manchester United               1.0
# 2             Calvin Bassey Yellow Card             Fulham               1.0
# 3             Harry Maguire Yellow Card  Manchester United               1.0
# 4                                   NaN                NaN               NaN
# ...                                 ...                ...               ...
# 14699        Donyell Malen Substitution        Aston Villa               1.0
# 14700        Donyell Malen Substitution        Aston Villa               2.0
# 14701  Christian Eriksen Penalty - Scor  Manchester United               1.0
# 14702                               NaN                NaN               NaN
# 14703              Casemiro Yellow Card  Manchester United               1.0
#
#            displayName_y positionName
# 0                    NaN          NaN
# 1            Mason Mount   Midfielder
# 2          Calvin Bassey     Defender
# 3          Harry Maguire     Defender
# 4                    NaN          NaN
# ...                  ...          ...
# 14699      Donyell Malen      Forward
# 14700      Morgan Rogers      Forward
# 14701  Christian Eriksen   Midfielder
# 14702                NaN          NaN
# 14703           Casemiro   Midfielder
#
# [14704 rows x 15 columns]

# %%
if not df_keyEvents.empty:

    season_name = df_keyEvents['seasonName'].iloc[0].replace(' ', '_').replace('/', '-')
    file_name = f"{season_name}_keyEvents_data.csv"


    df_keyEvents.to_csv(file_name, index=False)

    print(f"\nSuccessfully saved data to: {file_name}")
else:
    print("\nDataFrame was empty. No file was saved.")
# Out:
# Successfully saved data to: 2024-25_English_Premier_League_keyEvents_data.csv
