# %%
import pandas as pd
import os
import datetime
import kaggle
import zipfile

from directory import KAGGLE_DATASET_SLUG, KAGGLE_DATA_ROOT, BASE_DATA_DIR




if not os.path.exists(KAGGLE_DATA_ROOT):
    print(f"Data directory '{KAGGLE_DATA_ROOT}' not found. Downloading from Kaggle...")

    print(f"Downloading dataset '{KAGGLE_DATASET_SLUG}'...")
    kaggle.api.dataset_download_files(
        KAGGLE_DATASET_SLUG,
        path=data_dir,
        unzip=True
    )
    print(f"Download and unzip complete.")
else:
    print(f"Data directory '{KAGGLE_DATA_ROOT}' already exists. Skipping download.")

print("--- Loading base files... ---")
df_leagues = pd.read_csv(BASE_DATA_DIR + "/leagues.csv")
df_players = pd.read_csv(BASE_DATA_DIR + "/players.csv", low_memory=False)
df_teams = pd.read_csv(BASE_DATA_DIR + "/teams.csv")
df_fixtures = pd.read_csv(BASE_DATA_DIR + "/fixtures.csv")
df_teamStats = pd.read_csv(BASE_DATA_DIR + "/teamStats.csv")
df_teamRoster = pd.read_csv(BASE_DATA_DIR + "/teamRoster.csv")
df_keyEventDescription = pd.read_csv(BASE_DATA_DIR + "/keyEventDescription.csv")
df_status = pd.read_csv(BASE_DATA_DIR + "/status.csv")
df_venues = pd.read_csv(BASE_DATA_DIR + "/venues.csv")
df_standings = pd.read_csv(BASE_DATA_DIR + "/standings.csv")
print(" Base files loaded.")
# Out:
# Data directory './kaggle_data' already exists. Skipping download.
# --- Loading base files... ---
#  Base files loaded.

# %%
mySeasonType_input = input("Please enter the season ID: ")
mySeasonType = int(mySeasonType_input)
myTz = "US/Eastern"
todayDate = datetime.date.today().strftime("%Y-%m-%d")

df_fixtures['matchDateTimeLocal'] = pd.to_datetime(df_fixtures['date']).dt.tz_localize("UTC").dt.tz_convert(myTz)
df_fixtures['matchDate'] = pd.to_datetime(df_fixtures['matchDateTimeLocal']).dt.strftime("%Y-%m-%d")
df_fixtures['matchTime'] = pd.to_datetime(df_fixtures['matchDateTimeLocal']).dt.strftime("%H:%M")

df_soccer_fixtures = df_fixtures[df_fixtures['seasonType'].isin([mySeasonType])]

# %%
df_soccer_fixtures = pd.merge(df_soccer_fixtures, df_teams, how = "inner", left_on = ["homeTeamId"], right_on = ["teamId"])

df_soccer_fixtures = pd.merge(df_soccer_fixtures, df_teams, how = "inner", left_on = ["awayTeamId"], right_on = ["teamId"])


print(df_soccer_fixtures.info())
df_soccer_fixtures
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rn                     16 non-null     int64
#  1   seasonType             16 non-null     int64
#  2   leagueId               16 non-null     int64
#  3   eventId                16 non-null     int64
#  4   date                   16 non-null     object
#  5   venueId_x              16 non-null     int64
#  6   attendance             16 non-null     int64
#  7   homeTeamId             16 non-null     int64
#  8   awayTeamId             16 non-null     int64
#  9   homeTeamWinner         16 non-null     bool
#  10  awayTeamWinner         16 non-null     bool
#  11  homeTeamScore          16 non-null     int64
#  12  awayTeamScore          16 non-null     int64
#  13  homeTeamShootoutScore  16 non-null     int64
#  14  awayTeamShootoutScore  16 non-null     int64
#  15  statusId               16 non-null     int64
#  16  updateTime             16 non-null     object
#  17  matchDateTimeLocal     16 non-null     datetime64[ns, US/Eastern]
#  18  matchDate              16 non-null     object
#  19  matchTime              16 non-null     object
#  20  teamId_x               16 non-null     int64
#  21  location_x             16 non-null     object
#  22  name_x                 16 non-null     object
#  23  abbreviation_x         16 non-null     object
#  24  displayName_x          16 non-null     object
#  25  shortDisplayName_x     16 non-null     object
#  26  color_x                16 non-null     object
#  27  alternateColor_x       16 non-null     object
#  28  logoURL_x              16 non-null     object
#  29  venueId_y              16 non-null     int64
#  30  slug_x                 16 non-null     object
#  31  teamId_y               16 non-null     int64
#  32  location_y             16 non-null     object
#  33  name_y                 16 non-null     object
#  34  abbreviation_y         16 non-null     object
#  35  displayName_y          16 non-null     object
#  36  shortDisplayName_y     16 non-null     object
#  37  color_y                16 non-null     object
#  38  alternateColor_y       16 non-null     object
#  39  logoURL_y              16 non-null     object
#  40  venueId                16 non-null     int64
#  41  slug_y                 16 non-null     object
# dtypes: bool(2), datetime64[ns, US/Eastern](1), int64(17), object(22)
# memory usage: 5.2+ KB
# None
#     Rn  seasonType  leagueId  eventId                 date  venueId_x  \
# 0    1       12731      3920   720272  2024-09-17 18:30:00        214
# 1    2       12731      3920   720270  2024-09-17 18:45:00        201
# 2    3       12731      3920   720271  2024-09-17 18:45:00       4089
# 3    4       12731      3920   720275  2024-09-17 18:45:00        253
# 4    5       12731      3920   720280  2024-09-17 18:45:00       4248
# 5    6       12731      3920   720283  2024-09-17 18:45:00       8480
# 6    7       12731      3920   720269  2024-09-17 19:00:00        250
# 7    8       12731      3920   720278  2024-09-18 18:45:00       4440
# 8    9       12731      3920   720276  2024-09-18 19:00:00       1680
# 9   10       12731      3920   720268  2024-09-24 18:45:00       4036
# 10  11       12731      3920   720273  2024-09-24 18:45:00        134
# 11  12       12731      3920   720277  2024-09-24 18:45:00        249
# 12  13       12731      3920   720279  2024-09-24 19:00:00        215
# 13  14       12731      3920   720281  2024-09-25 18:45:00       2267
# 14  15       12731      3920   720274  2024-09-25 19:00:00        192
# 15  16       12731      3920   720282  2024-10-01 18:45:00       4684
#
#     attendance  homeTeamId  awayTeamId  homeTeamWinner  ...  \
# 0         8927         336        3891            True  ...
# 1         5530         394         370            True  ...
# 2        13945         334         384           False  ...
# 3        33842         368         376           False  ...
# 4         5429         346         399           False  ...
# 5        13634         337         309            True  ...
# 6            0         360         397            True  ...
# 7        16018         331         380            True  ...
# 8        24616         388         367           False  ...
# 9        40584         382         395            True  ...
# 10        8010         401         375           False  ...
# 11       38868         363         642            True  ...
# 12        8158         344         362           False  ...
# 13       59056         359         358            True  ...
# 14       60044         364         371            True  ...
# 15       51739         361        3802            True  ...
#
#                  location_y                   name_y  abbreviation_y  \
# 0            Fleetwood Town           Fleetwood Town             FLE
# 1                    Fulham                   Fulham             FUL
# 2            Crystal Palace           Crystal Palace             CRY
# 3               Southampton              Southampton             SOU
# 4       Sheffield Wednesday      Sheffield Wednesday             SHW
# 5             Leyton Orient            Leyton Orient             LEY
# 6                  Barnsley                 Barnsley             BAR
# 7   Wolverhampton Wanderers  Wolverhampton Wanderers             WOL
# 8         Tottenham Hotspur        Tottenham Hotspur             TOT
# 9                   Watford                  Watford             WAT
# 10           Leicester City           Leicester City             LEI
# 11                   Barrow                   Barrow             BRW
# 12              Aston Villa              Aston Villa             AVL
# 13         Bolton Wanderers         Bolton Wanderers             BOL
# 14          West Ham United          West Ham United             WHU
# 15            AFC Wimbledon            AFC Wimbledon             WIM
#
#               displayName_y  shortDisplayName_y  color_y alternateColor_y  \
# 0            Fleetwood Town      Fleetwood Town   C8142F           ffff00
# 1                    Fulham              Fulham   ffffff           d11317
# 2            Crystal Palace            C Palace   0202fb           ffdd00
# 3               Southampton         Southampton   ED1A3B           f1ee13
# 4       Sheffield Wednesday       Sheffield Wed   0000ff           ff4f00
# 5             Leyton Orient       Leyton Orient   C8142F           0e00f7
# 6                  Barnsley            Barnsley   f42727           065035
# 7   Wolverhampton Wanderers              Wolves   fdb913           cd1937
# 8         Tottenham Hotspur               Spurs   ffffff           9bafd8
# 9                   Watford             Watford   ffff00           1D428A
# 10           Leicester City           Leicester   0202fb           000000
# 11                   Barrow              Barrow   ffffff           deb887
# 12              Aston Villa         Aston Villa   660e36           ffffff
# 13         Bolton Wanderers              Bolton   ffffff           1a1a1a
# 14          West Ham United            West Ham   7c2c3b           000000
# 15            AFC Wimbledon           Wimbledon   0000d4           ffff00
#
#                                             logoURL_y venueId  \
# 0   https://a.espncdn.com/i/teamlogos/soccer/500/3...    3672
# 1   https://a.espncdn.com/i/teamlogos/soccer/500/3...     279
# 2   https://a.espncdn.com/i/teamlogos/soccer/500/3...     135
# 3   https://a.espncdn.com/i/teamlogos/soccer/500/3...    4850
# 4   https://a.espncdn.com/i/teamlogos/soccer/500/3...     183
# 5   https://a.espncdn.com/i/teamlogos/soccer/500/3...    3197
# 6   https://a.espncdn.com/i/teamlogos/soccer/500/3...     196
# 7   https://a.espncdn.com/i/teamlogos/soccer/500/3...     136
# 8   https://a.espncdn.com/i/teamlogos/soccer/500/3...    7827
# 9   https://a.espncdn.com/i/teamlogos/soccer/500/3...     203
# 10  https://a.espncdn.com/i/teamlogos/soccer/500/3...    5774
# 11  https://a.espncdn.com/i/teamlogos/soccer/500/6...    1349
# 12  https://a.espncdn.com/i/teamlogos/soccer/500/3...     307
# 13  https://a.espncdn.com/i/teamlogos/soccer/500/3...     256
# 14  https://a.espncdn.com/i/teamlogos/soccer/500/3...    6660
# 15  https://a.espncdn.com/i/teamlogos/soccer/500/3...    8528
#
#                           slug_y
# 0   team.fleetwood_town.betbrain
# 1                     eng.fulham
# 2             eng.crystal_palace
# 3                eng.southampton
# 4                  eng.sheff_wed
# 5              eng.leyton_orient
# 6                   eng.barnsley
# 7              eng.wolverhampton
# 8                  eng.tottenham
# 9                    eng.watford
# 10                 eng.leicester
# 11                   team.barrow
# 12               eng.aston_villa
# 13                    eng.bolton
# 14                  eng.west_ham
# 15        betbrain.afc_wimbledon
#
# [16 rows x 42 columns]

# %%
df_soccer_fixtures = df_soccer_fixtures.drop(columns='venueId')
df_soccer_fixtures = pd.merge(df_soccer_fixtures, df_venues, how = "inner", left_on = ["venueId_x"], right_on = ["venueId"])


df_soccer_fixtures
# Out:
#     Rn  seasonType  leagueId  eventId                 date  venueId_x  \
# 0    1       12731      3920   720272  2024-09-17 18:30:00        214
# 1    2       12731      3920   720270  2024-09-17 18:45:00        201
# 2    3       12731      3920   720271  2024-09-17 18:45:00       4089
# 3    4       12731      3920   720275  2024-09-17 18:45:00        253
# 4    5       12731      3920   720280  2024-09-17 18:45:00       4248
# 5    6       12731      3920   720283  2024-09-17 18:45:00       8480
# 6    7       12731      3920   720269  2024-09-17 19:00:00        250
# 7    8       12731      3920   720278  2024-09-18 18:45:00       4440
# 8    9       12731      3920   720276  2024-09-18 19:00:00       1680
# 9   10       12731      3920   720268  2024-09-24 18:45:00       4036
# 10  11       12731      3920   720273  2024-09-24 18:45:00        134
# 11  12       12731      3920   720277  2024-09-24 18:45:00        249
# 12  13       12731      3920   720279  2024-09-24 19:00:00        215
# 13  14       12731      3920   720281  2024-09-25 18:45:00       2267
# 14  15       12731      3920   720274  2024-09-25 19:00:00        192
# 15  16       12731      3920   720282  2024-10-01 18:45:00       4684
#
#     attendance  homeTeamId  awayTeamId  homeTeamWinner  ...  color_y  \
# 0         8927         336        3891            True  ...   C8142F
# 1         5530         394         370            True  ...   ffffff
# 2        13945         334         384           False  ...   0202fb
# 3        33842         368         376           False  ...   ED1A3B
# 4         5429         346         399           False  ...   0000ff
# 5        13634         337         309            True  ...   C8142F
# 6            0         360         397            True  ...   f42727
# 7        16018         331         380            True  ...   fdb913
# 8        24616         388         367           False  ...   ffffff
# 9        40584         382         395            True  ...   ffff00
# 10        8010         401         375           False  ...   0202fb
# 11       38868         363         642            True  ...   ffffff
# 12        8158         344         362           False  ...   660e36
# 13       59056         359         358            True  ...   ffffff
# 14       60044         364         371            True  ...   7c2c3b
# 15       51739         361        3802            True  ...   0000d4
#
#     alternateColor_y                                          logoURL_y  \
# 0             ffff00  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 1             d11317  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 2             ffdd00  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 3             f1ee13  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 4             ff4f00  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 5             0e00f7  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 6             065035  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 7             cd1937  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 8             9bafd8  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 9             1D428A  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 10            000000  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 11            deb887  https://a.espncdn.com/i/teamlogos/soccer/500/6...
# 12            ffffff  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 13            1a1a1a  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 14            000000  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 15            ffff00  https://a.espncdn.com/i/teamlogos/soccer/500/3...
#
#                           slug_y  venueId  \
# 0   team.fleetwood_town.betbrain      214
# 1                     eng.fulham      201
# 2             eng.crystal_palace     4089
# 3                eng.southampton      253
# 4                  eng.sheff_wed     4248
# 5              eng.leyton_orient     8480
# 6                   eng.barnsley      250
# 7              eng.wolverhampton     4440
# 8                  eng.tottenham     1680
# 9                    eng.watford     4036
# 10                 eng.leicester      134
# 11                   team.barrow      249
# 12               eng.aston_villa      215
# 13                    eng.bolton     2267
# 14                  eng.west_ham      192
# 15        betbrain.afc_wimbledon     4684
#
#                                fullName                         shortName  \
# 0                        bet365 Stadium                    bet365 Stadium
# 1                              Deepdale                              none
# 2                   MATRADE Loftus Road               MATRADE Loftus Road
# 3                         Goodison Park                              none
# 4                       Bloomfield Road                   Bloomfield Road
# 5               Gtech Community Stadium           Gtech Community Stadium
# 6                          Old Trafford                              none
# 7              American Express Stadium          American Express Stadium
# 8   The Coventry Building Society Arena  The Coventry Building Society Ar
# 9                        Etihad Stadium                    Etihad Stadium
# 10          Pallet-Track Bescot Stadium       Pallet-Track Bescot Stadium
# 11                      Stamford Bridge                              none
# 12                           Adams Park                              none
# 13                     Emirates Stadium                              none
# 14                              Anfield                              none
# 15                      St. James' Park                   St. James' Park
#
#    capacity                 city  country
# 0         0       Stoke-on-Trent  England
# 1         0              Preston  England
# 2         0               London  England
# 3         0            Liverpool  England
# 4         0            Blackpool  England
# 5         0               London  England
# 6         0           Manchester  England
# 7         0               Falmer  England
# 8         0             Coventry  England
# 9         0           Manchester  England
# 10        0              Walsall  England
# 11        0               London  England
# 12        0              Wycombe  England
# 13        0               London  England
# 14        0            Liverpool  England
# 15        0  Newcastle-upon-Tyne  England
#
# [16 rows x 47 columns]

# %%
df_soccer_fixtures = pd.merge(df_soccer_fixtures, df_status, how = "inner", left_on = ["statusId"], right_on = ["statusId"])
print(df_soccer_fixtures.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 50 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rn                     16 non-null     int64
#  1   seasonType             16 non-null     int64
#  2   leagueId               16 non-null     int64
#  3   eventId                16 non-null     int64
#  4   date                   16 non-null     object
#  5   venueId_x              16 non-null     int64
#  6   attendance             16 non-null     int64
#  7   homeTeamId             16 non-null     int64
#  8   awayTeamId             16 non-null     int64
#  9   homeTeamWinner         16 non-null     bool
#  10  awayTeamWinner         16 non-null     bool
#  11  homeTeamScore          16 non-null     int64
#  12  awayTeamScore          16 non-null     int64
#  13  homeTeamShootoutScore  16 non-null     int64
#  14  awayTeamShootoutScore  16 non-null     int64
#  15  statusId               16 non-null     int64
#  16  updateTime             16 non-null     object
#  17  matchDateTimeLocal     16 non-null     datetime64[ns, US/Eastern]
#  18  matchDate              16 non-null     object
#  19  matchTime              16 non-null     object
#  20  teamId_x               16 non-null     int64
#  21  location_x             16 non-null     object
#  22  name_x                 16 non-null     object
#  23  abbreviation_x         16 non-null     object
#  24  displayName_x          16 non-null     object
#  25  shortDisplayName_x     16 non-null     object
#  26  color_x                16 non-null     object
#  27  alternateColor_x       16 non-null     object
#  28  logoURL_x              16 non-null     object
#  29  venueId_y              16 non-null     int64
#  30  slug_x                 16 non-null     object
#  31  teamId_y               16 non-null     int64
#  32  location_y             16 non-null     object
#  33  name_y                 16 non-null     object
#  34  abbreviation_y         16 non-null     object
#  35  displayName_y          16 non-null     object
#  36  shortDisplayName_y     16 non-null     object
#  37  color_y                16 non-null     object
#  38  alternateColor_y       16 non-null     object
#  39  logoURL_y              16 non-null     object
#  40  slug_y                 16 non-null     object
#  41  venueId                16 non-null     int64
#  42  fullName               16 non-null     object
#  43  shortName              16 non-null     object
#  44  capacity               16 non-null     int64
#  45  city                   16 non-null     object
#  46  country                16 non-null     object
#  47  name                   16 non-null     object
#  48  state                  16 non-null     object
#  49  description            16 non-null     object
# dtypes: bool(2), datetime64[ns, US/Eastern](1), int64(18), object(29)
# memory usage: 6.2+ KB
# None

# %%
df_soccer_fixtures = pd.merge(df_soccer_fixtures, df_leagues, how = "inner", left_on = ["seasonType"], right_on = ["seasonType"])

df_soccer_fixtures
# Out:
#     Rn  seasonType  leagueId_x  eventId                 date  venueId_x  \
# 0    1       12731        3920   720272  2024-09-17 18:30:00        214
# 1    2       12731        3920   720270  2024-09-17 18:45:00        201
# 2    3       12731        3920   720271  2024-09-17 18:45:00       4089
# 3    4       12731        3920   720275  2024-09-17 18:45:00        253
# 4    5       12731        3920   720280  2024-09-17 18:45:00       4248
# 5    6       12731        3920   720283  2024-09-17 18:45:00       8480
# 6    7       12731        3920   720269  2024-09-17 19:00:00        250
# 7    8       12731        3920   720278  2024-09-18 18:45:00       4440
# 8    9       12731        3920   720276  2024-09-18 19:00:00       1680
# 9   10       12731        3920   720268  2024-09-24 18:45:00       4036
# 10  11       12731        3920   720273  2024-09-24 18:45:00        134
# 11  12       12731        3920   720277  2024-09-24 18:45:00        249
# 12  13       12731        3920   720279  2024-09-24 19:00:00        215
# 13  14       12731        3920   720281  2024-09-25 18:45:00       2267
# 14  15       12731        3920   720274  2024-09-25 19:00:00        192
# 15  16       12731        3920   720282  2024-10-01 18:45:00       4684
# 4   ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 5   ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 6   ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 7   ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 8   ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 9   ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 10  ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 11  ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 12  ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 13  ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 14  ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
# 15  ENG.LEAGUE_CUP  English Carabao Cup     Carabao Cup
#
# [16 rows x 57 columns]

# %%
#df_prem_fixtures
dropped_columns = ['seasonType', 'statusId', 'leagueId_x', 'date', 'venueId_x', 'homeTeamId', 'awayTeamId', 'homeTeamShootoutScore', 'awayTeamShootoutScore', 'teamId_x', 'updateTime', 'matchDateTimeLocal', 'location_x', 'name_x', 'abbreviation_x', 'shortDisplayName_x', 'color_x', 'alternateColor_x', 'logoURL_x', 'venueId_y', 'slug_x', 'teamId_y', 'location_y', 'name_y', 'abbreviation_y', 'shortDisplayName_y', 'color_y', 'alternateColor_y', 'logoURL_y', 'venueId', 'slug_y', 'shortName', 'capacity', 'city', 'country', 'name', 'state', 'seasonSlug', 'leagueId_y', 'midsizeName', 'leagueName', 'leagueShortName']

df_soccer_fixtures = df_soccer_fixtures.drop(columns=dropped_columns)

new_order = ['seasonName', 'eventId', 'matchDate', 'matchTime', 'fullName', 'attendance',  'displayName_x', 'displayName_y', 'homeTeamScore', 'awayTeamScore', 'homeTeamWinner', 'awayTeamWinner', 'description']

df_soccer_fixtures = df_soccer_fixtures[new_order]

#df_prem_fixtures['Venue'] = df_prem_fixtures['Venue'].str.replace('\\', '', regex=False)
df_soccer_fixtures=df_soccer_fixtures.rename(columns={'fullName': 'Venue', 'attendance': "Attendance", 'displayName_x': 'HomeTeam', "displayName_y": "AwayTeam", "homeTeamScore": "HomeTeamScore", "awayTeamScore": "AwayTeamScore", "description": "Description"})

df_soccer_fixtures.dropna(inplace=True)

# Create a dynamic filename based on the season name
# .iloc[0] gets the value from the first row
season_name = df_soccer_fixtures['seasonName'].iloc[0].replace(' ', '_').replace('/', '-')
file_name = f"{season_name}_fixtures.csv"

# Save the DataFrame to a CSV file in your project folder
# index=False prevents pandas from saving the row numbers as a column
df_soccer_fixtures.to_csv(file_name, index=False)

df_soccer_fixtures
# Out:
#                                   seasonName  eventId   matchDate matchTime  \
# 0   2024-25 English Carabao Cup, Third Round   720272  2024-09-17     14:30
# 1   2024-25 English Carabao Cup, Third Round   720270  2024-09-17     14:45
